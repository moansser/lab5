# %% [markdown]
# ## Классификация изображений
# ### Вводные слова
# Задача классификации изображений - это одна из ключевых задач в области компьютерного зрения и машинного обучения. Она заключается в том, чтобы разработать модель, способную автоматически определить, к какому классу или категории принадлежит данное изображение. Классификация используется в следующих задачах: классификация спектрограмм музыкальных записей для выявления предпочтений конкретного пользователя, классификация изображений для автоматической идентификации людей на фотографиях, кластеризация покупок пользователя в интернет-магазине для формирования целевой рекламы, и так далее
# ### Рекомендации
# Работу лучше выполнять в среде Google Colab, поскольку потребуется осуществлять вычисления на видеокарте. В Colab в меню нажмите на Изменить->Настройки блокнота и выберите доступный GPU. Это позволит использовать для обучения CUDA
# ### Цель работы и задачи
# В данной работе мы разработаем модель, для предсказания класса на датасете cifar-10. Ниже будет представлена baseline модель, основываясь на которой вы можете строить свою модель для классификации
# \
# Задачи, которые вам нужно решить в работе:
# \
# Обязательные:
# - Построить распределение классов в данных
# - Подготовить данные и обучить baseline-модель на датасете
# - Оценить качество модели
# - Написать свою модель и обучить ее
#
# Желательные:
# - Подумать об архитектуре модели, быть может стоит сделать ее глубже, добавить боковые связи и т.д.
# - Задуматься об аугментации
# - Попробовать transfer-learning
#
# \
# \
# Ваша работа будет оцениваться исходя из 2 факторов:
# - контрольная метрика
# - протокол исследования, которым и будет служить этот Jupyter-Notebook
#
# \
# Максимальный балл за работу - 20.
# \
# Удачи!

# %% [markdown]
# ## Baseline-модель

# %%
import torch
from tqdm import tqdm
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from torch.functional import F

# %% [markdown]
# Обучать мы будем, разумеется, на cuda, поэтому, создадим переменную device, которая будет зависеть от того, доступна ли видеокарта для вычислений

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f'Running on {device}')

# Функция для подсчета числа параметров
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# Running on cpu

# %%
class Baseline(nn.Module):
    def __init__(self, num_classes=10):
        super(Baseline, self).__init__()
        # Сверточные слои
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        # Полносвязные слои
        self.fc1 = nn.Linear(in_features=32 * 8 * 8, out_features=128)
        self.fc2 = nn.Linear(in_features=128, out_features=num_classes)
    
    def forward(self, x):
        # Прямой проход через сверточные слои
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        
        # Вытягивание в одномерный вектор
        x = x.view(x.size(0), -1)
        
        # Прямой проход через полносвязные слои
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %% [markdown]
# Загрузим данные, построим диаграммы для распределения классов и посмотрим на сами картинки

# %%
# Будем превращать картинку в torch.Tensor
transform = transforms.ToTensor()

# Загрузим датасеты для train и test
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)

# Получим метки классов
class_labels = train_dataset.classes
class_counts = np.array([0] * len(class_labels))

# Посчитаем число меток классов
for _, label in train_dataset:
    class_counts[label] += 1

class_counts = class_counts / class_counts.sum() * 100

# Построим диаграмму
plt.figure(figsize=(10, 8))
plt.bar(class_labels, class_counts)
plt.xlabel('Классы')
plt.ylabel('Количество изображений, %')
plt.title('Распределение классов в датасете CIFAR-10')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data\cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [53:35<00:00, 53.0kB/s]
# Extracting ./data\cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Случайным образом выберите 9 индексов из обучающего набора данных без повторений
indices = np.random.choice(len(train_dataset), 9, replace=False)

# Создайте сетку 3x3 для отображения изображений
fig, axes = plt.subplots(3, 3, figsize=(8, 8))  # Укажите размеры сетки и общий размер фигуры
for i, ax in enumerate(axes.flat):
    # Извлеките изображение и метку по выбранному индексу
    image, label = train_dataset[indices[i]]
    # Преобразуйте изображение из формата (C, H, W) в формат (H, W, C), необходимый для визуализации
    image = image.numpy().transpose((1, 2, 0))
    # Отобразите изображение на текущей оси
    ax.imshow(image)
    # Установите заголовок для отображения класса
    ax.set_title(f'Class: {label}')
    # Скрыть оси для более чистого отображения
    ax.axis('off')

# Вывести изображения на экран
plt.show()

# %% [markdown]
# Сделайте вывод о сбалансированности датасета:
# \
# Исходя из этого, какие метрики будем применять для оценки качества модели?

# %% [markdown]
# Датасет имеет сбалансированное распределение, поэтому для оценки качества модели можно использовать такие стандартные метрики, как Accuracy и Cross-Entropy Loss.

# %% [markdown]
# Напишем функции train и test

# %%
def train(model, train_loader, val_loader, criterion, optimizer, device, epochs=10):
    # Перевод модели в режим обучения
    model.train()
    # Перемещение модели на заданное устройство (например, GPU)
    model = model.to(device)
    # Инициализация списков для хранения значений потерь и точности
    train_loss_history = []
    train_acc_history = []
    val_loss_history = []
    val_acc_history = []
    for epoch in range(epochs):
        # Инициализация счетчиков для отслеживания потерь и точности на обучающей выборке
        running_loss = 0.0
        correct = 0
        total = 0
        # Использование tqdm для визуализации процесса обучения
        pbar = tqdm(enumerate(train_loader), total=len(train_loader), ncols=100, desc='Train epoch {}/{}'.format(epoch + 1, epochs))
        for batch_idx, (inputs, labels) in pbar:
            # Перемещение данных на устройство
            inputs, labels = inputs.to(device), labels.to(device)
            # Обнуление градиентов оптимизатора
            optimizer.zero_grad()
            # Прямой проход модели
            outputs = model(inputs)
            # Вычисление потерь
            loss = criterion(outputs, labels)
            # Обратный проход (вычисление градиентов)
            loss.backward()
            # Обновление параметров модели
            optimizer.step()
            # Накопление значений потерь
            running_loss += loss.item()
            # Подсчет точности предсказаний
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            # Обновление визуализации процесса обучения
            pbar.set_postfix({'loss': '{:.4f}'.format(running_loss / (batch_idx + 1)), 'accuracy': '{:.4f}'.format(correct / total)})
        # Сохранение результатов по потерям и точности для обучающей выборки
        train_loss_history.append(running_loss / len(train_loader))
        train_acc_history.append(correct / total)
        # Инициализация счетчиков для валидационной выборки
        correct = 0
        total = 0
        test_loss = 0.0
        # Использование tqdm для визуализации процесса валидации
        pbar = tqdm(enumerate(val_loader), total=len(val_loader), ncols=100, desc='Val {}/{}'.format(epoch + 1, epochs))
        with torch.no_grad():
            for batch_idx, (inputs, labels) in pbar:
                # Перемещение данных на устройство
                inputs, labels = inputs.to(device), labels.to(device)
                # Прямой проход модели
                outputs = model(inputs)
                # Вычисление потерь
                loss = criterion(outputs, labels)
                # Накопление значений потерь
                test_loss += loss.item()
                # Подсчет точности предсказаний
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                # Обновление визуализации процесса валидации
                pbar.set_postfix({'loss': '{:.4f}'.format(test_loss / (batch_idx + 1)), 'accuracy': '{:.4f}'.format(correct / total)})
        # Сохранение результатов по потерям и точности для валидационной выборки
        val_loss_history.append(test_loss / len(val_loader))
        val_acc_history.append(correct / total)
    # Возврат истории потерь и точности для анализа
    return train_loss_history, train_acc_history, val_loss_history, val_acc_history

def test(model, test_loader, criterion, device):
    # Перевод модели в режим оценки
    model.eval()
    # Инициализация счетчиков для потерь и точности
    correct = 0
    total = 0
    test_loss = 0.0
    # Отключение вычисления градиентов
    with torch.no_grad():
        for inputs, labels in test_loader:
            # Перемещение данных на устройство
            inputs, labels = inputs.to(device), labels.to(device)
            # Прямой проход модели
            outputs = model(inputs)
            # Вычисление потерь
            loss = criterion(outputs, labels)
            # Накопление значений потерь
            test_loss += loss.item()
            # Подсчет точности предсказаний
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    # Вычисление средней точности и потерь на тестовой выборке
    accuracy = correct / total
    average_loss = test_loss / len(test_loader)
    # Возврат точности и потерь
    return accuracy, average_loss

# %% [markdown]
# Сделайте разделение на train и val
# \
# Зачем так делать?

# %% [markdown]
# Обучающая выборка применяется для тренировки модели, позволяя ей выявлять закономерности и зависимости в данных. Валидационная выборка служит для оценки качества модели на новых, ранее не использованных данных, что помогает предотвратить переобучение и оптимизировать гиперпараметры.

# %%
# Определите размер обучающей выборки как 90% от общего количества данных
train_size = int(0.9 * len(train_dataset))

# Определите размер валидационной выборки как оставшиеся 10% данных
val_size = len(train_dataset) - train_size

# Разделите набор данных на обучающую и валидационную выборки
# Укажите параметр random_state для воспроизводимости и включите перемешивание данных
train_dataset, val_dataset = train_test_split(train_dataset, test_size=val_size, random_state=42, shuffle=True)

# %% [markdown]
# Создайте Dataloader'ы и настройте гиперпараметры, оптимизатор и функцию потерь
# \
# Какой оптимизатор будете использовать и почему, а какую loss-функцию?

# %% [markdown]
# В качестве оптимизатора я выберу Adam, так как он эффективно справляется с регуляризацией, что снижает риск переобучения. Функцию потерь использую CrossEntropyLoss, так как она идеально подходит для задач многоклассовой классификации.

# %%
# Гиперпараметры
learning_rate = 0.0005  # Обычно для большинства задач с нейронными сетями начинается с такого значения
num_epochs = 60  # Количество эпох для тренировки. Может быть увеличено в зависимости от задачи и результатов
batch_size = 512  # Размер батча (обычно выбирается в зависимости от доступной памяти)

# Создание модели
model = Baseline()

print('Model params: ', count_parameters(model))

# Определяем функцию потерь и оптимизатор
criterion = torch.nn.CrossEntropyLoss()  # Функция потерь для многоклассовой классификации (например, CIFAR-10)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  # Оптимизатор Adam, часто используется для обучения нейронных сетей

# Создание загрузчиков данных для тренировки, валидации и тестирования
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Model params:  268650

# %% [markdown]
# Обучите модель и постройте графики обучения

# %%
train_loss_history, train_acc_history, val_loss_history, val_acc_history = train(model, train_loader, val_loader, criterion, optimizer, device, epochs=num_epochs)
# Out:
# Train epoch 1/60: 100%|███████████████| 80/80 [00:13<00:00,  5.92it/s, loss=2.0381, accuracy=0.2621]
# Val 1/60: 100%|█████████████████████████| 9/9 [00:00<00:00, 12.55it/s, loss=1.8278, accuracy=0.3558]
# Train epoch 2/60: 100%|███████████████| 80/80 [00:14<00:00,  5.61it/s, loss=1.7222, accuracy=0.3883]
# Val 2/60: 100%|█████████████████████████| 9/9 [00:00<00:00, 11.07it/s, loss=1.6882, accuracy=0.3944]
# Train epoch 3/60: 100%|███████████████| 80/80 [00:16<00:00,  4.99it/s, loss=1.6206, accuracy=0.4204]
# Val 3/60: 100%|█████████████████████████| 9/9 [00:00<00:00,  9.67it/s, loss=1.5888, accuracy=0.4291]
# Train epoch 4/60: 100%|███████████████| 80/80 [00:17<00:00,  4.64it/s, loss=1.5560, accuracy=0.4447]
# Val 4/60: 100%|█████████████████████████| 9/9 [00:00<00:00,  9.15it/s, loss=1.5607, accuracy=0.4464]
# Train epoch 5/60: 100%|███████████████| 80/80 [00:17<00:00,  4.54it/s, loss=1.5074, accuracy=0.4666]
# Val 5/60: 100%|█████████████████████████| 9/9 [00:01<00:00,  8.85it/s, loss=1.5089, accuracy=0.4640]
# Train epoch 6/60: 100%|███████████████| 80/80 [00:18<00:00,  4.43it/s, loss=1.4669, accuracy=0.4783]
# Val 6/60: 100%|█████████████████████████| 9/9 [00:01<00:00,  8.96it/s, loss=1.4586, accuracy=0.4809]
# Train epoch 7/60: 100%|███████████████| 80/80 [00:17<00:00,  4.50it/s, loss=1.4167, accuracy=0.5002]
# Val 7/60: 100%|█████████████████████████| 9/9 [00:01<00:00,  8.94it/s, loss=1.4088, accuracy=0.5049]
# Train epoch 8/60: 100%|███████████████| 80/80 [00:17<00:00,  4.47it/s, loss=1.3823, accuracy=0.5129]
# Val 8/60: 100%|█████████████████████████| 9/9 [00:00<00:00,  9.03it/s, loss=1.3888, accuracy=0.5120]
# Train epoch 9/60: 100%|███████████████| 80/80 [00:17<00:00,  4.52it/s, loss=1.3379, accuracy=0.5280]
# Val 9/60: 100%|█████████████████████████| 9/9 [00:01<00:00,  8.48it/s, loss=1.3452, accuracy=0.5313]
# Train epoch 10/60: 100%|██████████████| 80/80 [00:17<00:00,  4.51it/s, loss=1.3022, accuracy=0.5407]
# Val 10/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.20it/s, loss=1.3263, accuracy=0.5336]
# Train epoch 11/60: 100%|██████████████| 80/80 [00:17<00:00,  4.56it/s, loss=1.2762, accuracy=0.5478]
# Val 11/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.17it/s, loss=1.2988, accuracy=0.5444]
# Train epoch 12/60: 100%|██████████████| 80/80 [00:17<00:00,  4.54it/s, loss=1.2514, accuracy=0.5593]
# Val 12/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.31it/s, loss=1.3044, accuracy=0.5453]
# Train epoch 13/60: 100%|██████████████| 80/80 [00:17<00:00,  4.57it/s, loss=1.2201, accuracy=0.5691]
# Val 13/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.07it/s, loss=1.2538, accuracy=0.5591]
# Train epoch 14/60: 100%|██████████████| 80/80 [00:17<00:00,  4.49it/s, loss=1.1984, accuracy=0.5771]
# Val 14/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.26it/s, loss=1.2307, accuracy=0.5722]
# Train epoch 15/60: 100%|██████████████| 80/80 [00:18<00:00,  4.35it/s, loss=1.1763, accuracy=0.5857]
# Val 15/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.08it/s, loss=1.2116, accuracy=0.5847]
# Train epoch 16/60: 100%|██████████████| 80/80 [00:17<00:00,  4.55it/s, loss=1.1605, accuracy=0.5907]
# Val 16/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.06it/s, loss=1.2127, accuracy=0.5853]
# Train epoch 17/60: 100%|██████████████| 80/80 [00:17<00:00,  4.51it/s, loss=1.1453, accuracy=0.5970]
# Val 17/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.05it/s, loss=1.1917, accuracy=0.5829]
# Train epoch 18/60: 100%|██████████████| 80/80 [00:18<00:00,  4.44it/s, loss=1.1274, accuracy=0.6048]
# Val 18/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.17it/s, loss=1.1753, accuracy=0.5944]
# Train epoch 19/60: 100%|██████████████| 80/80 [00:17<00:00,  4.61it/s, loss=1.1197, accuracy=0.6082]
# Val 19/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.37it/s, loss=1.1740, accuracy=0.5940]
# Train epoch 20/60: 100%|██████████████| 80/80 [00:19<00:00,  4.20it/s, loss=1.1046, accuracy=0.6136]
# Val 20/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.45it/s, loss=1.1403, accuracy=0.6078]
# Train epoch 21/60: 100%|██████████████| 80/80 [00:17<00:00,  4.53it/s, loss=1.0810, accuracy=0.6211]
# Val 21/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.42it/s, loss=1.1445, accuracy=0.6062]
# Train epoch 22/60: 100%|██████████████| 80/80 [00:18<00:00,  4.38it/s, loss=1.0679, accuracy=0.6256]
# Val 22/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.91it/s, loss=1.1614, accuracy=0.6004]
# Train epoch 23/60: 100%|██████████████| 80/80 [00:17<00:00,  4.52it/s, loss=1.0617, accuracy=0.6288]
# Val 23/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.10it/s, loss=1.1492, accuracy=0.6062]
# Train epoch 24/60: 100%|██████████████| 80/80 [00:17<00:00,  4.64it/s, loss=1.0483, accuracy=0.6337]
# Val 24/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.12it/s, loss=1.1439, accuracy=0.6042]
# Train epoch 25/60: 100%|██████████████| 80/80 [00:17<00:00,  4.47it/s, loss=1.0400, accuracy=0.6362]
# Val 25/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.92it/s, loss=1.1191, accuracy=0.6124]
# Train epoch 26/60: 100%|██████████████| 80/80 [00:17<00:00,  4.52it/s, loss=1.0227, accuracy=0.6416]
# Val 26/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.07it/s, loss=1.1387, accuracy=0.6011]
# Train epoch 27/60: 100%|██████████████| 80/80 [00:17<00:00,  4.55it/s, loss=1.0064, accuracy=0.6483]
# Val 27/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.11it/s, loss=1.0853, accuracy=0.6267]
# Train epoch 28/60: 100%|██████████████| 80/80 [00:17<00:00,  4.53it/s, loss=1.0025, accuracy=0.6500]
# Val 28/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.14it/s, loss=1.0921, accuracy=0.6218]
# Train epoch 29/60: 100%|██████████████| 80/80 [00:17<00:00,  4.55it/s, loss=0.9860, accuracy=0.6566]
# Val 29/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.55it/s, loss=1.0806, accuracy=0.6287]
# Train epoch 30/60: 100%|██████████████| 80/80 [00:17<00:00,  4.59it/s, loss=0.9768, accuracy=0.6591]
# Val 30/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.45it/s, loss=1.0592, accuracy=0.6382]
# Train epoch 31/60: 100%|██████████████| 80/80 [00:17<00:00,  4.54it/s, loss=0.9668, accuracy=0.6627]
# Val 31/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.10it/s, loss=1.0614, accuracy=0.6331]
# Train epoch 32/60: 100%|██████████████| 80/80 [00:17<00:00,  4.61it/s, loss=0.9532, accuracy=0.6664]
# Val 32/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.13it/s, loss=1.0460, accuracy=0.6371]
# Train epoch 33/60: 100%|██████████████| 80/80 [00:17<00:00,  4.45it/s, loss=0.9478, accuracy=0.6704]
# Val 33/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.21it/s, loss=1.0391, accuracy=0.6429]
# Train epoch 34/60: 100%|██████████████| 80/80 [00:17<00:00,  4.50it/s, loss=0.9458, accuracy=0.6722]
# Val 34/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.16it/s, loss=1.0721, accuracy=0.6340]
# Train epoch 35/60: 100%|██████████████| 80/80 [00:18<00:00,  4.37it/s, loss=0.9355, accuracy=0.6748]
# Val 35/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.95it/s, loss=1.0624, accuracy=0.6384]
# Train epoch 36/60: 100%|██████████████| 80/80 [00:17<00:00,  4.54it/s, loss=0.9155, accuracy=0.6820]
# Val 36/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.58it/s, loss=1.0451, accuracy=0.6391]
# Train epoch 37/60: 100%|██████████████| 80/80 [00:18<00:00,  4.37it/s, loss=0.9140, accuracy=0.6832]
# Val 37/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.99it/s, loss=1.0185, accuracy=0.6531]
# Train epoch 38/60: 100%|██████████████| 80/80 [00:17<00:00,  4.49it/s, loss=0.8966, accuracy=0.6887]
# Val 38/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.40it/s, loss=1.0300, accuracy=0.6504]
# Train epoch 39/60: 100%|██████████████| 80/80 [00:17<00:00,  4.49it/s, loss=0.8988, accuracy=0.6878]
# Val 39/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.07it/s, loss=1.0470, accuracy=0.6398]
# Train epoch 40/60: 100%|██████████████| 80/80 [00:17<00:00,  4.59it/s, loss=0.8847, accuracy=0.6927]
# Val 40/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.42it/s, loss=1.0266, accuracy=0.6507]
# Train epoch 41/60: 100%|██████████████| 80/80 [00:17<00:00,  4.56it/s, loss=0.8767, accuracy=0.6971]
# Val 41/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.04it/s, loss=1.0172, accuracy=0.6582]
# Train epoch 42/60: 100%|██████████████| 80/80 [00:17<00:00,  4.56it/s, loss=0.8654, accuracy=0.7004]
# Val 42/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.32it/s, loss=1.0082, accuracy=0.6576]
# Train epoch 43/60: 100%|██████████████| 80/80 [00:17<00:00,  4.50it/s, loss=0.8641, accuracy=0.7003]
# Val 43/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.80it/s, loss=1.0041, accuracy=0.6578]
# Train epoch 44/60: 100%|██████████████| 80/80 [00:17<00:00,  4.55it/s, loss=0.8510, accuracy=0.7045]
# Val 44/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.19it/s, loss=1.0005, accuracy=0.6540]
# Train epoch 45/60: 100%|██████████████| 80/80 [00:17<00:00,  4.59it/s, loss=0.8439, accuracy=0.7090]
# Val 45/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.44it/s, loss=1.0653, accuracy=0.6351]
# Train epoch 46/60: 100%|██████████████| 80/80 [00:17<00:00,  4.56it/s, loss=0.8371, accuracy=0.7088]
# Val 46/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.00it/s, loss=0.9977, accuracy=0.6567]
# Train epoch 47/60: 100%|██████████████| 80/80 [00:18<00:00,  4.42it/s, loss=0.8290, accuracy=0.7156]
# Val 47/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.14it/s, loss=1.0019, accuracy=0.6598]
# Train epoch 48/60: 100%|██████████████| 80/80 [00:17<00:00,  4.61it/s, loss=0.8197, accuracy=0.7176]
# Val 48/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.44it/s, loss=1.0136, accuracy=0.6584]
# Train epoch 49/60: 100%|██████████████| 80/80 [00:17<00:00,  4.58it/s, loss=0.8148, accuracy=0.7190]
# Val 49/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.94it/s, loss=1.0151, accuracy=0.6609]
# Train epoch 50/60: 100%|██████████████| 80/80 [00:17<00:00,  4.56it/s, loss=0.8081, accuracy=0.7203]
# Val 50/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.27it/s, loss=1.0007, accuracy=0.6582]
# Train epoch 51/60: 100%|██████████████| 80/80 [00:17<00:00,  4.59it/s, loss=0.7993, accuracy=0.7235]
# Val 51/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.18it/s, loss=0.9851, accuracy=0.6651]
# Train epoch 52/60: 100%|██████████████| 80/80 [00:17<00:00,  4.63it/s, loss=0.7887, accuracy=0.7286]
# Val 52/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.45it/s, loss=1.0059, accuracy=0.6553]
# Train epoch 53/60: 100%|██████████████| 80/80 [00:17<00:00,  4.58it/s, loss=0.7907, accuracy=0.7276]
# Val 53/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.98it/s, loss=0.9971, accuracy=0.6573]
# Train epoch 54/60: 100%|██████████████| 80/80 [00:18<00:00,  4.39it/s, loss=0.7803, accuracy=0.7309]
# Val 54/60: 100%|████████████████████████| 9/9 [00:01<00:00,  8.28it/s, loss=0.9815, accuracy=0.6680]
# Train epoch 55/60: 100%|██████████████| 80/80 [00:17<00:00,  4.60it/s, loss=0.7724, accuracy=0.7327]
# Val 55/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.37it/s, loss=1.0034, accuracy=0.6584]
# Train epoch 56/60: 100%|██████████████| 80/80 [00:16<00:00,  4.71it/s, loss=0.7641, accuracy=0.7357]
# Val 56/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.26it/s, loss=1.0013, accuracy=0.6609]
# Train epoch 57/60: 100%|██████████████| 80/80 [00:17<00:00,  4.66it/s, loss=0.7634, accuracy=0.7359]
# Val 57/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.43it/s, loss=0.9958, accuracy=0.6602]
# Train epoch 58/60: 100%|██████████████| 80/80 [00:17<00:00,  4.60it/s, loss=0.7544, accuracy=0.7391]
# Val 58/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.41it/s, loss=0.9712, accuracy=0.6704]
# Train epoch 59/60: 100%|██████████████| 80/80 [00:17<00:00,  4.60it/s, loss=0.7479, accuracy=0.7406]
# Val 59/60: 100%|████████████████████████| 9/9 [00:01<00:00,  7.04it/s, loss=0.9853, accuracy=0.6671]
# Train epoch 60/60: 100%|██████████████| 80/80 [00:17<00:00,  4.48it/s, loss=0.7374, accuracy=0.7457]
# Val 60/60: 100%|████████████████████████| 9/9 [00:00<00:00,  9.12it/s, loss=0.9825, accuracy=0.6664]

# %%
epochs = range(1, len(train_loss_history) + 1)

# График функции потерь на тренировочных данных
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss_history, 'b', label='Train Loss')
plt.plot(epochs, val_loss_history, 'r', label='Validation Loss')
plt.title('Train and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# График точности на валидационных данных
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc_history, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc_history, 'g', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Сделайте выводы о качестве обучения

# %% [markdown]
# Модель демонстрирует положительную динамику обучения: кривые потерь и точности изменяются в правильном направлении. Стабилизация валидационной точности указывает на то, что модель достигла своего предельного потенциала для данного набора данных.

# %% [markdown]
# Оцените тестовую метрику на тестовых данных

# %%
test_acc, test_loss = test(model, test_loader, criterion, device)
print('Test Loss: {:.4f}\nTest Accuracy: {:.4f}'.format(test_loss, test_acc))
# Out:
# Test Loss: 0.9807
# Test Accuracy: 0.6649

# %% [markdown]
# ## Что дальше?
# Теперь, когда у вас есть все необходимое - экспериментируйте. Можете изменить все что угодно, креативность поощряется. Используйте новые модели, loss-функции, аугментацию, ансамбли, выдумывайте все, что сможете

# %% [markdown]
# ## Критерии оценки
# Accuracy - на тестовых данных
# - $Accuracy \leq 0.67$ - 0 баллов
# - $0.67 < Accuracy \leq 0.72$ - 2 балла
# - $0.72 < Accuracy \leq 0.77$ - 4 балла
# - $0.77 < Accuracy \leq 0.82$ - 6 баллов
# - $0.82 < Accuracy \leq 0.87$ - 8 баллов
# - $Accuracy > 0.87$ - 10 баллов
